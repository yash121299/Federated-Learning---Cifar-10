# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
print(torch.__version__)
# Out:
# 2.4.1+cu121

# %%
gpu = torch.cuda.is_available()
if not gpu:
  device = "cpu"
else:
  device = "cuda"

# %%
device
# Out:
# 'cuda'

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
transform = transforms.Compose([
                                transforms.RandomHorizontalFlip(p=0.3),
                                transforms.RandomApply([transforms.RandomRotation(10)], p=0.3),
                                transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),
                                # transforms.RandomApply([transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0))], p=0.2),
                                transforms.ToTensor(),
                                # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])

# %%
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49613330.51it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
n_workers = 0
batch_size = 20
valid_size = 0.3

# %%
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=n_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=valid_sampler, num_workers=n_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,
    num_workers=n_workers)

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer (sees 32x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        # convolutional layer (sees 16x16x16 tensor)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        # convolutional layer (sees 8x8x32 tensor)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # linear layer (64 * 4 * 4 -> 500)
        self.fc1 = nn.Linear(64 * 4 * 4, 500)
        # linear layer (500 -> 10)
        self.fc2 = nn.Linear(500, 10)
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        # flatten image input
        x = x.view(-1, 64 * 4 * 4)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = self.fc2(x)
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
model.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# number of epochs to train the model
n_epochs = 100

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)

    ######################
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss
        valid_loss += loss.item()*data.size(0)

    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)

    # print training/validation statistics
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))

    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.584776 	Validation Loss: 0.622504
# Validation loss decreased (inf --> 0.622504).  Saving model ...
# Epoch: 2 	Training Loss: 1.409436 	Validation Loss: 0.583073
# Validation loss decreased (0.622504 --> 0.583073).  Saving model ...
# Epoch: 3 	Training Loss: 1.298375 	Validation Loss: 0.520248
# Validation loss decreased (0.583073 --> 0.520248).  Saving model ...
# Epoch: 4 	Training Loss: 1.193267 	Validation Loss: 0.476264
# Validation loss decreased (0.520248 --> 0.476264).  Saving model ...
# Epoch: 5 	Training Loss: 1.117571 	Validation Loss: 0.449549
# Validation loss decreased (0.476264 --> 0.449549).  Saving model ...
# Epoch: 6 	Training Loss: 1.062951 	Validation Loss: 0.434316
# Validation loss decreased (0.449549 --> 0.434316).  Saving model ...
# Epoch: 7 	Training Loss: 1.020235 	Validation Loss: 0.412485
# Validation loss decreased (0.434316 --> 0.412485).  Saving model ...
# Epoch: 8 	Training Loss: 0.983298 	Validation Loss: 0.400658
# Validation loss decreased (0.412485 --> 0.400658).  Saving model ...
# Epoch: 9 	Training Loss: 0.953539 	Validation Loss: 0.388459
# Validation loss decreased (0.400658 --> 0.388459).  Saving model ...
# Epoch: 10 	Training Loss: 0.923371 	Validation Loss: 0.375040
# Validation loss decreased (0.388459 --> 0.375040).  Saving model ...
# Epoch: 11 	Training Loss: 0.895561 	Validation Loss: 0.370232
# Validation loss decreased (0.375040 --> 0.370232).  Saving model ...
# Epoch: 12 	Training Loss: 0.871193 	Validation Loss: 0.351954
# Validation loss decreased (0.370232 --> 0.351954).  Saving model ...
# Epoch: 13 	Training Loss: 0.842340 	Validation Loss: 0.337458
# Validation loss decreased (0.351954 --> 0.337458).  Saving model ...
# Epoch: 14 	Training Loss: 0.818411 	Validation Loss: 0.332462
# Validation loss decreased (0.337458 --> 0.332462).  Saving model ...
# Epoch: 15 	Training Loss: 0.797307 	Validation Loss: 0.340642
# Epoch: 16 	Training Loss: 0.775631 	Validation Loss: 0.310868
# Validation loss decreased (0.332462 --> 0.310868).  Saving model ...
# Epoch: 17 	Training Loss: 0.757403 	Validation Loss: 0.315071
# Epoch: 18 	Training Loss: 0.741601 	Validation Loss: 0.306107
# Validation loss decreased (0.310868 --> 0.306107).  Saving model ...
# Epoch: 19 	Training Loss: 0.722426 	Validation Loss: 0.305322
# Validation loss decreased (0.306107 --> 0.305322).  Saving model ...
# Epoch: 20 	Training Loss: 0.707870 	Validation Loss: 0.291481
# Validation loss decreased (0.305322 --> 0.291481).  Saving model ...
# Epoch: 21 	Training Loss: 0.689483 	Validation Loss: 0.284438
# Validation loss decreased (0.291481 --> 0.284438).  Saving model ...
# Epoch: 22 	Training Loss: 0.678204 	Validation Loss: 0.285501
# Epoch: 23 	Training Loss: 0.668779 	Validation Loss: 0.278012
# Validation loss decreased (0.284438 --> 0.278012).  Saving model ...
# Epoch: 24 	Training Loss: 0.651029 	Validation Loss: 0.274764
# Validation loss decreased (0.278012 --> 0.274764).  Saving model ...
# Epoch: 25 	Training Loss: 0.645002 	Validation Loss: 0.263765
# Validation loss decreased (0.274764 --> 0.263765).  Saving model ...
# Epoch: 26 	Training Loss: 0.629796 	Validation Loss: 0.268657
# Epoch: 27 	Training Loss: 0.619978 	Validation Loss: 0.262043
# Validation loss decreased (0.263765 --> 0.262043).  Saving model ...
# Epoch: 28 	Training Loss: 0.608228 	Validation Loss: 0.257300
# Validation loss decreased (0.262043 --> 0.257300).  Saving model ...
# Epoch: 29 	Training Loss: 0.595882 	Validation Loss: 0.257685
# Epoch: 30 	Training Loss: 0.588288 	Validation Loss: 0.253455
# Validation loss decreased (0.257300 --> 0.253455).  Saving model ...
# Epoch: 31 	Training Loss: 0.583856 	Validation Loss: 0.255837
# Epoch: 32 	Training Loss: 0.574593 	Validation Loss: 0.250066
# Validation loss decreased (0.253455 --> 0.250066).  Saving model ...
# Epoch: 33 	Training Loss: 0.565986 	Validation Loss: 0.242571
# Validation loss decreased (0.250066 --> 0.242571).  Saving model ...
# Epoch: 34 	Training Loss: 0.560031 	Validation Loss: 0.240096
# Validation loss decreased (0.242571 --> 0.240096).  Saving model ...
# Epoch: 35 	Training Loss: 0.550926 	Validation Loss: 0.239280
# Validation loss decreased (0.240096 --> 0.239280).  Saving model ...
# Epoch: 36 	Training Loss: 0.540987 	Validation Loss: 0.242827
# Epoch: 37 	Training Loss: 0.536336 	Validation Loss: 0.245129
# Epoch: 38 	Training Loss: 0.533882 	Validation Loss: 0.241795
# Epoch: 39 	Training Loss: 0.526872 	Validation Loss: 0.231747
# Validation loss decreased (0.239280 --> 0.231747).  Saving model ...
# Epoch: 40 	Training Loss: 0.519143 	Validation Loss: 0.234209
# Epoch: 41 	Training Loss: 0.511370 	Validation Loss: 0.231761
# Epoch: 42 	Training Loss: 0.503582 	Validation Loss: 0.232833
# Epoch: 43 	Training Loss: 0.500546 	Validation Loss: 0.231018
# Validation loss decreased (0.231747 --> 0.231018).  Saving model ...
# Epoch: 44 	Training Loss: 0.494129 	Validation Loss: 0.221755
# Validation loss decreased (0.231018 --> 0.221755).  Saving model ...
# Epoch: 45 	Training Loss: 0.485346 	Validation Loss: 0.224357
# Epoch: 46 	Training Loss: 0.485665 	Validation Loss: 0.223859
# Epoch: 47 	Training Loss: 0.481592 	Validation Loss: 0.226147
# Epoch: 48 	Training Loss: 0.475249 	Validation Loss: 0.224264
# Epoch: 49 	Training Loss: 0.469166 	Validation Loss: 0.220464
# Validation loss decreased (0.221755 --> 0.220464).  Saving model ...
# Epoch: 50 	Training Loss: 0.460957 	Validation Loss: 0.227768
# Epoch: 51 	Training Loss: 0.466438 	Validation Loss: 0.217869
# Validation loss decreased (0.220464 --> 0.217869).  Saving model ...
# Epoch: 52 	Training Loss: 0.461094 	Validation Loss: 0.218836
# Epoch: 53 	Training Loss: 0.453139 	Validation Loss: 0.214894
# Validation loss decreased (0.217869 --> 0.214894).  Saving model ...
# Epoch: 54 	Training Loss: 0.450142 	Validation Loss: 0.214970
# Epoch: 55 	Training Loss: 0.447895 	Validation Loss: 0.217326
# Epoch: 56 	Training Loss: 0.439874 	Validation Loss: 0.217225
# Epoch: 57 	Training Loss: 0.438041 	Validation Loss: 0.216704
# Epoch: 58 	Training Loss: 0.438384 	Validation Loss: 0.217025
# Epoch: 59 	Training Loss: 0.431250 	Validation Loss: 0.216369
# Epoch: 60 	Training Loss: 0.429078 	Validation Loss: 0.215176
# Epoch: 61 	Training Loss: 0.424769 	Validation Loss: 0.214433
# Validation loss decreased (0.214894 --> 0.214433).  Saving model ...
# Epoch: 62 	Training Loss: 0.418710 	Validation Loss: 0.210669
# Validation loss decreased (0.214433 --> 0.210669).  Saving model ...
# Epoch: 63 	Training Loss: 0.415876 	Validation Loss: 0.210336
# Validation loss decreased (0.210669 --> 0.210336).  Saving model ...
# Epoch: 64 	Training Loss: 0.411792 	Validation Loss: 0.213245
# Epoch: 65 	Training Loss: 0.413334 	Validation Loss: 0.215256
# Epoch: 66 	Training Loss: 0.408660 	Validation Loss: 0.214561
# Epoch: 67 	Training Loss: 0.404691 	Validation Loss: 0.215419
# Epoch: 68 	Training Loss: 0.411821 	Validation Loss: 0.207491
# Validation loss decreased (0.210336 --> 0.207491).  Saving model ...
# Epoch: 69 	Training Loss: 0.398181 	Validation Loss: 0.214791
# Epoch: 70 	Training Loss: 0.393267 	Validation Loss: 0.209572
# Epoch: 71 	Training Loss: 0.393854 	Validation Loss: 0.216335
# Epoch: 72 	Training Loss: 0.392138 	Validation Loss: 0.213238
# Epoch: 73 	Training Loss: 0.389145 	Validation Loss: 0.210729
# Epoch: 74 	Training Loss: 0.384626 	Validation Loss: 0.206353
# Validation loss decreased (0.207491 --> 0.206353).  Saving model ...
# Epoch: 75 	Training Loss: 0.387431 	Validation Loss: 0.203575
# Validation loss decreased (0.206353 --> 0.203575).  Saving model ...
# Epoch: 76 	Training Loss: 0.380312 	Validation Loss: 0.209607
# Epoch: 77 	Training Loss: 0.375828 	Validation Loss: 0.206615
# Epoch: 78 	Training Loss: 0.380090 	Validation Loss: 0.208262
# Epoch: 79 	Training Loss: 0.367631 	Validation Loss: 0.206699
# Epoch: 80 	Training Loss: 0.375876 	Validation Loss: 0.209764
# Epoch: 81 	Training Loss: 0.370332 	Validation Loss: 0.204486
# Epoch: 82 	Training Loss: 0.365646 	Validation Loss: 0.202083
# Validation loss decreased (0.203575 --> 0.202083).  Saving model ...
# Epoch: 83 	Training Loss: 0.369848 	Validation Loss: 0.205252
# Epoch: 84 	Training Loss: 0.365069 	Validation Loss: 0.204239
# Epoch: 85 	Training Loss: 0.361350 	Validation Loss: 0.207130
# Epoch: 86 	Training Loss: 0.360760 	Validation Loss: 0.208696
# Epoch: 87 	Training Loss: 0.357559 	Validation Loss: 0.217735
# Epoch: 88 	Training Loss: 0.355401 	Validation Loss: 0.203866
# Epoch: 89 	Training Loss: 0.358836 	Validation Loss: 0.206002
# Epoch: 90 	Training Loss: 0.354966 	Validation Loss: 0.204352
# Epoch: 91 	Training Loss: 0.347278 	Validation Loss: 0.205766
# Epoch: 92 	Training Loss: 0.354270 	Validation Loss: 0.204765
# Epoch: 93 	Training Loss: 0.350038 	Validation Loss: 0.204444
# Epoch: 94 	Training Loss: 0.345435 	Validation Loss: 0.205073
# Epoch: 95 	Training Loss: 0.351676 	Validation Loss: 0.205012
# Epoch: 96 	Training Loss: 0.348156 	Validation Loss: 0.204193
# Epoch: 97 	Training Loss: 0.343924 	Validation Loss: 0.198104
# Validation loss decreased (0.202083 --> 0.198104).  Saving model ...
# Epoch: 98 	Training Loss: 0.333719 	Validation Loss: 0.204040
# Epoch: 99 	Training Loss: 0.335935 	Validation Loss: 0.204756
# Epoch: 100 	Training Loss: 0.340400 	Validation Loss: 0.203162

# %%
model.load_state_dict(torch.load('model_cifar.pt'))
# Out:
# <ipython-input-17-30c1fa6c7551>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model_cifar.pt'))
# <All keys matched successfully>

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.684216
#
# Test Accuracy of airplane: 80% (809/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 68% (688/1000)
# Test Accuracy of   cat: 53% (532/1000)
# Test Accuracy of  deer: 73% (735/1000)
# Test Accuracy of   dog: 68% (685/1000)
# Test Accuracy of  frog: 83% (831/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 84% (840/1000)
# Test Accuracy of truck: 82% (820/1000)
#
# Test Accuracy (Overall): 76% (7672/10000)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = next(dataiter)
images.numpy()

# move model inputs to cuda, if GPU available
if gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
